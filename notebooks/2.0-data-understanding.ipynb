# %% [markdown]
# # **Data Undestanding**

# %% [markdown]
# #### Importing Libs and Loading Data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

house_data = pd.read_csv("../data/raw/kc_house_data.csv")

# %% [markdown]
# #### Exploratory Data Analysis

# %% [markdown]
# ##### Descriptive Statistics

# %%
house_data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house_data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
house_data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ##### Univariate Analysis

# %% [markdown]
# ![assimetria](..\notebooks\assimetry.png)

# %%
mean = house_data.price.mean()
skewness = house_data.price.skew()
median = house_data.price.median()
std = house_data.price.std()
iqr = house_data.price.describe()['75%'] - house_data.price.describe()['25%']
lower_limit = house_data.price.describe()['75%'] - 1.5 * iqr
upper_limit = house_data.price.describe()['25%'] + 1.5 * iqr

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 8))

sns.histplot(data=house_data, x='price', kde=True, ax=axes[0], bins=30, color='teal')
axes[0].set_title('House Price Hist Distribution')
axes[0].set_xlabel('Price (millions)')
axes[0].set_ylabel('Count')
axes[0].set_facecolor('#eaeaf2')
axes[0].axvline(mean, label='Mean', color='purple', linestyle='dashed', linewidth=2)
axes[0].annotate(f'Skewness = {skewness:.2f}', xy=(0.8, 0.9), xycoords='axes fraction', fontsize=9)
axes[0].annotate(f'Mean = {mean / 1000000 :.2f}', xy=(0.8, 0.82), xycoords='axes fraction', fontsize=9)
axes[0].annotate(f'Std = {std / 1000000 :.2f}', xy=(0.8, 0.74), xycoords='axes fraction', fontsize=9)
axes[0].legend(loc='upper right', title='Legend')
axes[0].grid(True)

sns.boxplot(house_data, y='price', ax=axes[1], color='teal')
axes[1].set_title('House Price Box Distribution')
axes[1].set_ylabel('Price (millions)')
axes[1].set_facecolor('#eaeaf2')
axes[1].annotate(f'Median = {median / 1000000 :.2f}', xy=(0.8, 0.9), xycoords='axes fraction', fontsize=9)
axes[1].grid(True)

plt.tight_layout()

plt.show()

# %%
palette = ['teal']

fig, axes = plt.subplots(2, 1, figsize=(12, 8))

sns.countplot(data=house_data, x='bedrooms', hue='bedrooms', palette=palette, alpha=0.6, ax=axes[0])
axes[0].set_title('Property Count By Bedrooms')
axes[0].set_xlabel('Number of bedrooms')  
axes[0].set_ylabel('Count') 
axes[0].set_facecolor('#eaeaf2')
axes[0].legend([],[], frameon=False)

sns.countplot(data=house_data, x='bathrooms', hue='bathrooms', palette=palette, alpha=0.7, ax=axes[1])
axes[1].set_title('Property Count By Bathrooms')
axes[1].set_xlabel('Number of bathrooms')  
axes[1].set_ylabel('Count') 
axes[1].set_facecolor('#eaeaf2')
axes[1].legend([],[], frameon=False)

plt.tight_layout()

plt.show()

# %%
mean = house_data.sqft_living.mean()
skewness = house_data.sqft_living.skew()
median = house_data.sqft_living.median()
std = house_data.sqft_living.std()
iqr = house_data.sqft_living.describe()['75%'] - house_data.sqft_living.describe()['25%']
lower_limit = house_data.sqft_living.describe()['75%'] - 1.5 * iqr
upper_limit = house_data.sqft_living.describe()['25%'] + 1.5 * iqr

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 8))

sns.histplot(data=house_data, x='sqft_living', kde=True, ax=axes[0], bins=30, color='teal')
axes[0].set_title('Square Feet Living Hist')
axes[0].set_xlabel('Size (Feets²)')
axes[0].set_ylabel('Count')
axes[0].set_facecolor('#eaeaf2')
axes[0].axvline(mean, label='Mean', color='purple', linestyle='dashed', linewidth=2)
axes[0].annotate(f'Skewness = {skewness:.2f}', xy=(0.8, 0.9), xycoords='axes fraction', fontsize=9)
axes[0].annotate(f'Mean = {mean:.2f}', xy=(0.8, 0.82), xycoords='axes fraction', fontsize=9)
axes[0].annotate(f'Std = {std:.2f}', xy=(0.8, 0.74), xycoords='axes fraction', fontsize=9)
axes[0].legend(loc='upper right', title='Legend')
axes[0].grid(True)

sns.boxplot(house_data, y='sqft_living', ax=axes[1], color='teal')
axes[1].set_title('Square Feet Living Box')
axes[1].set_ylabel('Size (Feets²)')
axes[1].set_facecolor('#eaeaf2')
axes[1].annotate(f'Median = {median:.2f}', xy=(0.8, 0.9), xycoords='axes fraction', fontsize=9)
axes[1].grid(True)

plt.tight_layout()

plt.show()

# %%
mean = house_data.sqft_lot.mean()
skewness = house_data.sqft_lot.skew()
median = house_data.sqft_lot.median()
std = house_data.sqft_lot.std()
iqr = house_data.sqft_lot.describe()['75%'] - house_data.sqft_lot.describe()['25%']
lower_limit = house_data.sqft_lot.describe()['75%'] - 1.5 * iqr
upper_limit = house_data.sqft_lot.describe()['25%'] + 1.5 * iqr

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 8))

sns.histplot(data=house_data, x='sqft_lot', kde=True, ax=axes[0], bins=30, color='teal')
axes[0].set_title('Square Feet Lot Hist')
axes[0].set_xlabel('Size (feets²)')
axes[0].set_ylabel('Count')
axes[0].set_facecolor('#eaeaf2')
axes[0].axvline(mean, label='Mean', color='purple', linestyle='dashed', linewidth=2)
axes[0].annotate(f'Skewness = {skewness:.2f}', xy=(0.8, 0.9), xycoords='axes fraction', fontsize=9)
axes[0].annotate(f'Mean = {mean:.2f}', xy=(0.8, 0.82), xycoords='axes fraction', fontsize=9)
axes[0].annotate(f'Std = {std:.2f}', xy=(0.8, 0.74), xycoords='axes fraction', fontsize=9)
axes[0].legend(loc='upper right', title='Legend')
axes[0].grid(True)

sns.boxplot(house_data, y='sqft_lot', ax=axes[1], color='teal')
axes[1].set_title('Square Feet Lot Box')
axes[1].set_ylabel('Size (feets²)')
axes[1].set_facecolor('#eaeaf2')
axes[1].annotate(f'Median = {median:.2f}', xy=(0.8, 0.9), xycoords='axes fraction', fontsize=9)
axes[1].grid(True)

plt.tight_layout()

plt.show()

# %%
palette = ['teal', 'purple', 'navy', 'blue', 'red', 'coral']

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))

sns.countplot(data=house_data, x='floors', hue='floors', palette=palette, alpha=0.6, ax=axes[0, 0])
axes[0, 0].set_title('Property Count By Floors')
axes[0, 0].set_xlabel('Number of floors')  
axes[0, 0].set_ylabel('Count') 
axes[0, 0].set_facecolor('#eaeaf2')

sns.countplot(data=house_data, x='waterfront', hue='waterfront', palette=palette, alpha=0.6, ax=axes[0, 1])
axes[0, 1].set_title('Property Count By Waterfront Status')
axes[0, 1].set_xlabel('Waterfront status')  
axes[0, 1].set_ylabel('Count') 
axes[0, 1].set_facecolor('#eaeaf2')

sns.countplot(data=house_data, x='view', hue='view', palette=palette, alpha=0.6, ax=axes[1, 0])
axes[1, 0].set_title('Property Count By Views')
axes[1, 0].set_xlabel('Number of views')  
axes[1, 0].set_ylabel('Count') 
axes[1, 0].set_facecolor('#eaeaf2')

sns.countplot(data=house_data, x='condition', hue='condition', palette=palette, alpha=0.6, ax=axes[1, 1])
axes[1, 1].set_title('Property Count By Condition Level')
axes[1, 1].set_xlabel('Condition level')  
axes[1, 1].set_ylabel('Count') 
axes[1, 1].set_facecolor('#eaeaf2')

plt.tight_layout()

plt.show()

# %%
mean = house_data.sqft_above.mean()
skewness = house_data.sqft_above.skew()
median = house_data.sqft_above.median()
std = house_data.sqft_above.std()
iqr = house_data.sqft_above.describe()['75%'] - house_data.sqft_above.describe()['25%']
lower_limit = house_data.sqft_above.describe()['75%'] - 1.5 * iqr
upper_limit = house_data.sqft_above.describe()['25%'] + 1.5 * iqr

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 8))

sns.histplot(data=house_data, x='sqft_above', kde=True, ax=axes[0], bins=30, color='teal')
axes[0].set_title('Square Feet Above Hist')
axes[0].set_xlabel('Size (feets²)')
axes[0].set_ylabel('Count')
axes[0].set_facecolor('#eaeaf2')
axes[0].axvline(mean, label='Mean', color='purple', linestyle='dashed', linewidth=2)
axes[0].annotate(f'Skewness = {skewness:.2f}', xy=(0.8, 0.9), xycoords='axes fraction', fontsize=9)
axes[0].annotate(f'Mean = {mean:.2f}', xy=(0.8, 0.82), xycoords='axes fraction', fontsize=9)
axes[0].annotate(f'Std = {std:.2f}', xy=(0.8, 0.74), xycoords='axes fraction', fontsize=9)
axes[0].legend(loc='upper right', title='Legend')
axes[0].grid(True)

sns.boxplot(house_data, y='sqft_above', ax=axes[1], color='teal')
axes[1].set_title('Square Feet Above Box')
axes[1].set_ylabel('Size (feets²)')
axes[1].set_facecolor('#eaeaf2')
axes[1].annotate(f'Median = {median:.2f}', xy=(0.8, 0.9), xycoords='axes fraction', fontsize=9)
axes[1].grid(True)

plt.tight_layout()

plt.show()

# %%
mean = house_data.sqft_basement.mean()
skewness = house_data.sqft_basement.skew()
median = house_data.sqft_basement.median()
std = house_data.sqft_basement.std()
iqr = house_data.sqft_basement.describe()['75%'] - house_data.sqft_basement.describe()['25%']
lower_limit = house_data.sqft_basement.describe()['75%'] - 1.5 * iqr
upper_limit = house_data.sqft_basement.describe()['25%'] + 1.5 * iqr

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 8))

sns.histplot(data=house_data, x='sqft_basement', kde=True, ax=axes[0], bins=30, color='teal')
axes[0].set_title('Square Feet Above Hist')
axes[0].set_xlabel('Size (feets²)')
axes[0].set_ylabel('Count')
axes[0].set_facecolor('#eaeaf2')
axes[0].axvline(mean, label='Mean', color='purple', linestyle='dashed', linewidth=2)
axes[0].annotate(f'Skewness = {skewness:.2f}', xy=(0.8, 0.9), xycoords='axes fraction', fontsize=9)
axes[0].annotate(f'Mean = {mean:.2f}', xy=(0.8, 0.82), xycoords='axes fraction', fontsize=9)
axes[0].annotate(f'Std = {std:.2f}', xy=(0.8, 0.74), xycoords='axes fraction', fontsize=9)
axes[0].legend(loc='upper right', title='Legend')
axes[0].grid(True)

sns.boxplot(house_data, y='sqft_basement', ax=axes[1], color='teal')
axes[1].set_title('Square Feet Above Box')
axes[1].set_ylabel('Size (feets²)')
axes[1].set_facecolor('#eaeaf2')
axes[1].annotate(f'Median = {median:.2f}', xy=(0.8, 0.9), xycoords='axes fraction', fontsize=9)
axes[1].grid(True)

plt.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 8))

sns.lineplot(data=house_data['yr_built'].value_counts().sort_index(), marker='o', color='teal', alpha=0.6, ax=axes[0])
axes[0].set_title('Number of Houses Built Over Time')
axes[0].set_xlabel('Year built')
axes[0].set_ylabel('Count')
axes[0].set_facecolor('#eaeaf2') 
axes[0].grid(True)

sns.lineplot(data=house_data.loc[house_data['yr_renovated'] != 0, 'yr_renovated'].value_counts().sort_index(), marker='o', color='teal', alpha=0.6, ax=axes[1])
axes[1].set_title('Number of Houses Renovated Over Time')
axes[1].set_xlabel('Year renovated')
axes[1].set_ylabel('Count')
axes[1].set_facecolor('#eaeaf2') 
axes[1].grid(True)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### Bivariate Analysis

# %% [markdown]
# ![assimetria](..\notebooks\boxplot.png)

# %%
plt.figure(figsize=(12, 6))

ax = sns.scatterplot(data=house_data, x='sqft_living', y='price', color='teal', alpha=0.6)
ax.set_title('Price X Sqft Living')
ax.set_xlabel('Size (feets²)')
ax.set_ylabel('Price (millions)')
ax.set_facecolor('#eaeaf2') 
ax.grid(True)

plt.tight_layout()

plt.show()

# %%
palette = ['teal', 'purple']

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))

sns.boxplot(data=house_data, x='bedrooms', y='price', color='teal', ax=axes[0, 0])
axes[0, 0].set_title('Price X Bedrooms')
axes[0, 0].set_xlabel('Number of bedrooms')
axes[0, 0].set_ylabel('Price (millions)')
axes[0, 0].set_facecolor('#eaeaf2') 
axes[0, 0].grid(True)

sns.boxplot(data=house_data, x='bathrooms', y='price', color='teal', ax=axes[0, 1])
axes[0, 1].set_title('Price X Bathrooms')
axes[0, 1].set_xlabel('Number of bathrooms')
axes[0, 1].set_ylabel('Price (millions)')
axes[0, 1].set_xticklabels(axes[0, 1].get_xticklabels(), rotation=90) 
axes[0, 1].set_facecolor('#eaeaf2') 
axes[0, 1].grid(True)

sns.boxplot(data=house_data, x='floors', y='price', color='teal', ax=axes[1, 0])
axes[1, 0].set_title('Price X Floors')
axes[1, 0].set_xlabel('Number of floors')
axes[1, 0].set_ylabel('Price (millions)')
axes[1, 0].set_facecolor('#eaeaf2') 
axes[1, 0].grid(True)


sns.boxplot(data=house_data, x='waterfront', y='price', hue='waterfront', palette=palette, ax=axes[1, 1])
axes[1, 1].set_title('Price X Waterfront Status')
axes[1, 1].set_xlabel('Waterfront status')
axes[1, 1].set_ylabel('Price (millions)')
axes[1, 1].set_facecolor('#eaeaf2') 
axes[1, 1].grid(True)

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(12, 6))

ax = sns.boxplot(data=house_data, x='bedrooms', y='bathrooms', color='teal')
plt.title('Bedrooms X Bathrooms')
plt.xlabel('Number of bedrooms')
plt.ylabel('Number of bathrooms')
ax.set_facecolor('#eaeaf2')
plt.grid(True)

plt.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))

sns.barplot(data=house_data, x='bedrooms', y='price', color='teal', alpha=0.6, ax=axes[0, 0])
axes[0, 0].set_title('Average Price by Number of Bedrooms')
axes[0, 0].set_xlabel('Number of bedrooms')
axes[0, 0].set_ylabel('Price (millions)')
axes[0, 0].set_facecolor('#eaeaf2') 

sns.barplot(data=house_data, x='bathrooms', y='price', color='teal', alpha=0.6, ax=axes[0, 1])
axes[0, 1].set_title('Average Price by Number of Bathrooms')
axes[0, 1].set_xlabel('Number of bathooms')
axes[0, 1].set_ylabel('Price (millions)')
axes[0, 1].set_xticklabels(axes[0, 1].get_xticklabels(), rotation=90) 
axes[0, 1].set_facecolor('#eaeaf2') 

sns.barplot(data=house_data, x='floors', y='price', color='teal', alpha=0.6, ax=axes[1, 0])
axes[1, 0].set_title('Average Price by Number of Floors')
axes[1, 0].set_xlabel('Number of floors')
axes[1, 0].set_ylabel('Price (millions)')
axes[1, 0].set_facecolor('#eaeaf2') 

sns.barplot(data=house_data, x='waterfront', y='price', color='teal', alpha=0.6, width=0.7, ax=axes[1, 1])
axes[1, 1].set_title('Average Price by Waterfront Status')
axes[1, 1].set_xlabel('Waterfront status')
axes[1, 1].set_ylabel('Price (millions)')
axes[1, 1].set_facecolor('#eaeaf2') 

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=house_data.sort_values('yr_built'), x='yr_built', y='price', ci=None, color='teal')
plt.title('Average Price Over Time')
plt.xlabel('Year Built')
plt.ylabel('Price (millions)')
ax.set_facecolor('#eaeaf2')
plt.grid(True)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### Multivariate Analysis

# %% [markdown]
# ![correlação de pearson](..\notebooks\pearson-corr.png)

# %%
selected_columns = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement']

labels = ['Price', 'Bedrooms', 'Bathrooms', 'Sqft living', 'Sqft lot', 'Floors', 'Sqft above', 'Sqft basement']

selected_data = house_data[selected_columns]

correlation_matrix = selected_data.corr()

plt.figure(figsize=(12, 5), facecolor='#eaeaf2')

ax = sns.heatmap(data=correlation_matrix,
                xticklabels=labels,
                yticklabels=labels,
                annot=True, 
                cmap='coolwarm',
                center=0,
                vmin=-1,
                vmax=1,
                square=True,
                fmt='.2f',
                linewidths=0.7,
                cbar=True
)   
                
plt.title('Correlation of Housing Features')

plt.tight_layout()

plt.show()

# %%
selected_columns = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot']

plt.figure(figsize=(12, 6))

pairplot = sns.pairplot(data=house_data, vars=selected_columns, markers='o', palette=['teal', 'purple'], hue='waterfront')

pairplot.fig.suptitle('Pairwise Comparison of Housing Features by Waterfront Status', y=1.02) 

for ax in pairplot.axes.flatten():
    ax.set_facecolor('#eaeaf2')
    ax.grid(True, linestyle='--', linewidth=0.7)

labels = ['Price (millions)', 'Bedrooms', 'Bathrooms', 'Sqft Living (feets²)', 'Sqft Lot (feets²)']

for i, label in enumerate(labels):
    for j, sublabel in enumerate(labels):
        if i == j:
            pairplot.axes[i, j].set_xlabel(label)
            pairplot.axes[i, j].set_ylabel(label)
        else:
            pairplot.axes[i, j].set_xlabel(sublabel)
            pairplot.axes[i, j].set_ylabel(label)

pairplot._legend.set_bbox_to_anchor((0.96, 0.99))
pairplot._legend.set_title('Waterfront Status') 
pairplot._legend.set_frame_on(True)  

plt.tight_layout()

plt.show()
